# %% [markdown]
# ### Print Prime Numbers
# Write a python function that takes an integer and checks for prime number. If the input is prime number then print the result. For example if the input number is 3, then print "The number 10 is prime". If not print "The number 10 is not prime". Then create a range X form 1 to 100(both inclusive) and for each number in X call the function.
# Use magic command to print the time taken to execute the full program.
#
# Hint: Refer to https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %%
def is_prime(n):
    from math import sqrt
    if n<2 :
        print("The number {} is not prime.\n".format(n))
        #prime numbers can not be less than "2"
    elif n==2 or n==3 :
        print("The number {} is prime.\n".format(n))
        # 2 and 3 are prime numbers
    else :
        #divisibility check for n with the numbers less than sqrt(n)
        for i in range(2,1+int(sqrt(n))) :
            if n%i == 0 :
                print("The number {} is not prime.\n".format(n))
                break
            elif i==int(sqrt(n)) :
                print("The number {} is prime.\n".format(n))
            ##for numbers that are greater than sqrt(n), they are not required to be checked

# %%
# %%time
is_prime(10)
# Out:
# The number 10 is not prime.
#
# CPU times: user 445 µs, sys: 35 µs, total: 480 µs
# Wall time: 485 µs

# %%
# %%time
for i in range(1,101):
    is_prime(i)
# Out:
# The number 1 is not prime.
#
# The number 2 is prime.
#
# The number 3 is prime.
#
# The number 4 is not prime.
#
# The number 5 is prime.
#
# The number 6 is not prime.
#
# The number 7 is prime.
#
# The number 8 is not prime.
#
# The number 9 is not prime.
#
# The number 10 is not prime.
#
# The number 11 is prime.
#
# The number 12 is not prime.
#
# The number 13 is prime.
#
# The number 14 is not prime.
#
# The number 15 is not prime.
#
# The number 16 is not prime.
#
# The number 17 is prime.
#
# The number 18 is not prime.
#
# The number 19 is prime.
#
# The number 20 is not prime.
#
# The number 21 is not prime.
#
# The number 22 is not prime.
#
# The number 23 is prime.
#
# The number 24 is not prime.
#
# The number 25 is not prime.
#
# The number 26 is not prime.
#
# The number 27 is not prime.
#
# The number 28 is not prime.
#
# The number 29 is prime.
#
# The number 30 is not prime.
#
# The number 31 is prime.
#
# The number 32 is not prime.
#
# ...
